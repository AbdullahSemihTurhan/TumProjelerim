# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDİzisi1=np.linspace(10,100,20)

# %%
numpyDİzisi1
# Out:
# array([ 10.        ,  14.73684211,  19.47368421,  24.21052632,
#         28.94736842,  33.68421053,  38.42105263,  43.15789474,
#         47.89473684,  52.63157895,  57.36842105,  62.10526316,
#         66.84210526,  71.57894737,  76.31578947,  81.05263158,
#         85.78947368,  90.52631579,  95.26315789, 100.        ])

# %%
numpyDİzisi2=numpyDİzisi1**2

# %%
numpyDİzisi2
# Out:
# array([  100.        ,   217.17451524,   379.22437673,   586.14958449,
#          837.9501385 ,  1134.62603878,  1476.17728532,  1862.60387812,
#         2293.90581717,  2770.08310249,  3291.13573407,  3857.06371191,
#         4467.86703601,  5123.54570637,  5824.09972299,  6569.52908587,
#         7359.83379501,  8195.01385042,  9075.06925208, 10000.        ])

# %%
(benimFigur,benimEksen)=pyt.subplots()
benimEksen.plot(numpyDİzisi1,numpyDİzisi2,color="#808080",alpha=0.3) #alpha saydamlik katar
benimEksen.plot(numpyDİzisi2,numpyDİzisi1,"b")

# %% [markdown]
# # renk kodlari

# %% [markdown]
# rgb hex code diyerek arat ve renk kodlarini renk tanimladiginiz yere color=kodu yaz ustteki ornek giibi yap

# %% [markdown]
# # Grafik Cizgi

# %%
(yeniFigur,yeniEksen)=plt.subplots()
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 50,color="g",linewidth=5,linestyle="-.")
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 25,color="b",linewidth=2,linestyle="--")

yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 75,color="r",linewidth=5)
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 125,color="y",linewidth=2)
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 100,color="#808080",linestyle=":")
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 150,color="#000000",linestyle="--",marker="+")#marker veri noktalarina koy demek

yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 175,color="#000080",linestyle="--",marker="+",markerfacecolor="#000080") #+ nın icini doldurur
yeniEksen.plot(numpyDİzisi1,numpyDİzisi1 + 200,color="#800080",linestyle="--",marker="o",markersize=10 ,markerfacecolor="r") #o nın icini doldurur ve boyutunu ayarlar
#ici dolabilecek seylerde iclerini doldurur markerfacecolor="renkkodu" ile

# %% [markdown]
# # scatter

# %%
plt.scatter(numpyDİzisi1,numpyDİzisi2) # verileri hazır grafige dondurur

# %% [markdown]
# # histogram

# %%
yenidizinp=np.random.randint(0,100,50)

# %%
yenidizinp
# Out:
# array([93,  6, 42, 73, 94, 78, 14, 67, 48, 81, 47, 41, 95,  7, 14, 34, 29,
#        83,  8, 61, 88, 63, 37, 57, 42, 93, 88, 63, 62, 96, 80, 29, 39, 73,
#        73, 24, 52, 18, 46, 63,  2, 32, 87, 93, 54, 95, 33, 74, 26, 76])

# %%
plt.hist(yenidizinp) # verileri alttaki sekle cevirir
# Out:
# (array([ 4.,  3.,  4.,  5.,  6.,  3.,  6.,  5.,  4., 10.]),
#  array([ 2. , 11.4, 20.8, 30.2, 39.6, 49. , 58.4, 67.8, 77.2, 86.6, 96. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # boxplot

# %%
plt.boxplot(yenidizinp) #verilerin dagilimini gosterir
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2101a303550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2101a303c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2101a3031f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2101a30f2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2101a30f610>],
#  'means': []}
